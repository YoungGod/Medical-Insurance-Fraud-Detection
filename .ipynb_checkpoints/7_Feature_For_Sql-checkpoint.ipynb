# %%
import numpy as np

# %% [markdown]
# # 各个条目统计

# %%
item_list = []
for line in open("feature_item.txt","r"):
    item_list.append(line.strip())
for item in item_list:
    print "sum({}) as sum_{}, avg({}) as avg_{}, median({}) as mid_{},stddev({}) as std_{}, max({}) as max_{},".format(item,item,item,item,item,item,item,item,item,item)
# Out:
# sum(yp_occur) as sum_yp_occur, avg(yp_occur) as avg_yp_occur, median(yp_occur) as mid_yp_occur,stddev(yp_occur) as std_yp_occur, max(yp_occur) as max_yp_occur,
# sum(gzyp_occur) as sum_gzyp_occur, avg(gzyp_occur) as avg_gzyp_occur, median(gzyp_occur) as mid_gzyp_occur,stddev(gzyp_occur) as std_gzyp_occur, max(gzyp_occur) as max_gzyp_occur,
# sum(gcy_occur) as sum_gcy_occur, avg(gcy_occur) as avg_gcy_occur, median(gcy_occur) as mid_gcy_occur,stddev(gcy_occur) as std_gcy_occur, max(gcy_occur) as max_gcy_occur,
# sum(zcy_occur) as sum_zcy_occur, avg(zcy_occur) as avg_zcy_occur, median(zcy_occur) as mid_zcy_occur,stddev(zcy_occur) as std_zcy_occur, max(zcy_occur) as max_zcy_occur,
# sum(yp_self) as sum_yp_self, avg(yp_self) as avg_yp_self, median(yp_self) as mid_yp_self,stddev(yp_self) as std_yp_self, max(yp_self) as max_yp_self,
# sum(yp_refuse) as sum_yp_refuse, avg(yp_refuse) as avg_yp_refuse, median(yp_refuse) as mid_yp_refuse,stddev(yp_refuse) as std_yp_refuse, max(yp_refuse) as max_yp_refuse,
# sum(yp_declare) as sum_yp_declare, avg(yp_declare) as avg_yp_declare, median(yp_declare) as mid_yp_declare,stddev(yp_declare) as std_yp_declare, max(yp_declare) as max_yp_declare,
# sum(jc_occur) as sum_jc_occur, avg(jc_occur) as avg_jc_occur, median(jc_occur) as mid_jc_occur,stddev(jc_occur) as std_jc_occur, max(jc_occur) as max_jc_occur,
# sum(gzjc_occur) as sum_gzjc_occur, avg(gzjc_occur) as avg_gzjc_occur, median(gzjc_occur) as mid_gzjc_occur,stddev(gzjc_occur) as std_gzjc_occur, max(gzjc_occur) as max_gzjc_occur,
# sum(jc_self) as sum_jc_self, avg(jc_self) as avg_jc_self, median(jc_self) as mid_jc_self,stddev(jc_self) as std_jc_self, max(jc_self) as max_jc_self,
# sum(jc_declare) as sum_jc_declare, avg(jc_declare) as avg_jc_declare, median(jc_declare) as mid_jc_declare,stddev(jc_declare) as std_jc_declare, max(jc_declare) as max_jc_declare,
# sum(zl_occur) as sum_zl_occur, avg(zl_occur) as avg_zl_occur, median(zl_occur) as mid_zl_occur,stddev(zl_occur) as std_zl_occur, max(zl_occur) as max_zl_occur,
# sum(zl_self) as sum_zl_self, avg(zl_self) as avg_zl_self, median(zl_self) as mid_zl_self,stddev(zl_self) as std_zl_self, max(zl_self) as max_zl_self,
# sum(zl_declare) as sum_zl_declare, avg(zl_declare) as avg_zl_declare, median(zl_declare) as mid_zl_declare,stddev(zl_declare) as std_zl_declare, max(zl_declare) as max_zl_declare,
# sum(ss_occur) as sum_ss_occur, avg(ss_occur) as avg_ss_occur, median(ss_occur) as mid_ss_occur,stddev(ss_occur) as std_ss_occur, max(ss_occur) as max_ss_occur,
# sum(ss_self) as sum_ss_self, avg(ss_self) as avg_ss_self, median(ss_self) as mid_ss_self,stddev(ss_self) as std_ss_self, max(ss_self) as max_ss_self,
# sum(ss_declare) as sum_ss_declare, avg(ss_declare) as avg_ss_declare, median(ss_declare) as mid_ss_declare,stddev(ss_declare) as std_ss_declare, max(ss_declare) as max_ss_declare,
# sum(cw_occur) as sum_cw_occur, avg(cw_occur) as avg_cw_occur, median(cw_occur) as mid_cw_occur,stddev(cw_occur) as std_cw_occur, max(cw_occur) as max_cw_occur,
# sum(cw_declare) as sum_cw_declare, avg(cw_declare) as avg_cw_declare, median(cw_declare) as mid_cw_declare,stddev(cw_declare) as std_cw_declare, max(cw_declare) as max_cw_declare,
# sum(yycl_occur) as sum_yycl_occur, avg(yycl_occur) as avg_yycl_occur, median(yycl_occur) as mid_yycl_occur,stddev(yycl_occur) as std_yycl_occur, max(yycl_occur) as max_yycl_occur,
# sum(gjcl_occur) as sum_gjcl_occur, avg(gjcl_occur) as avg_gjcl_occur, median(gjcl_occur) as mid_gjcl_occur,stddev(gjcl_occur) as std_gjcl_occur, max(gjcl_occur) as max_gjcl_occur,
# sum(yycl_self) as sum_yycl_self, avg(yycl_self) as avg_yycl_self, median(yycl_self) as mid_yycl_self,stddev(yycl_self) as std_yycl_self, max(yycl_self) as max_yycl_self,
# sum(sqx_declare) as sum_sqx_declare, avg(sqx_declare) as avg_sqx_declare, median(sqx_declare) as mid_sqx_declare,stddev(sqx_declare) as std_sqx_declare, max(sqx_declare) as max_sqx_declare,
# sum(cfsx_declare) as sum_cfsx_declare, avg(cfsx_declare) as avg_cfsx_declare, median(cfsx_declare) as mid_cfsx_declare,stddev(cfsx_declare) as std_cfsx_declare, max(cfsx_declare) as max_cfsx_declare,
# sum(qt_occure) as sum_qt_occure, avg(qt_occure) as avg_qt_occure, median(qt_occure) as mid_qt_occure,stddev(qt_occure) as std_qt_occure, max(qt_occure) as max_qt_occure,
# sum(qt_declare) as sum_qt_declare, avg(qt_declare) as avg_qt_declare, median(qt_declare) as mid_qt_declare,stddev(qt_declare) as std_qt_declare, max(qt_declare) as max_qt_declare,
# sum(ycx_declare) as sum_ycx_declare, avg(ycx_declare) as avg_ycx_declare, median(ycx_declare) as mid_ycx_declare,stddev(ycx_declare) as std_ycx_declare, max(ycx_declare) as max_ycx_declare,
# sum(sqx_self) as sum_sqx_self, avg(sqx_self) as avg_sqx_self, median(sqx_self) as mid_sqx_self,stddev(sqx_self) as std_sqx_self, max(sqx_self) as max_sqx_self,
# sum(std_pay) as sum_std_pay, avg(std_pay) as avg_std_pay, median(std_pay) as mid_std_pay,stddev(std_pay) as std_std_pay, max(std_pay) as max_std_pay,
# sum(self_over_std) as sum_self_over_std, avg(self_over_std) as avg_self_over_std, median(self_over_std) as mid_self_over_std,stddev(self_over_std) as std_self_over_std, max(self_over_std) as max_self_over_std,
# sum(med_assist) as sum_med_assist, avg(med_assist) as avg_med_assist, median(med_assist) as mid_med_assist,stddev(med_assist) as std_med_assist, max(med_assist) as max_med_assist,
# sum(over_upper_limit) as sum_over_upper_limit, avg(over_upper_limit) as avg_over_upper_limit, median(over_upper_limit) as mid_over_upper_limit,stddev(over_upper_limit) as std_over_upper_limit, max(over_upper_limit) as max_over_upper_limit,
# sum(med_insurance) as sum_med_insurance, avg(med_insurance) as avg_med_insurance, median(med_insurance) as mid_med_insurance,stddev(med_insurance) as std_med_insurance, max(med_insurance) as max_med_insurance,
# sum(servant_assist) as sum_servant_assist, avg(servant_assist) as avg_servant_assist, median(servant_assist) as mid_servant_assist,stddev(servant_assist) as std_servant_assist, max(servant_assist) as max_servant_assist,
# sum(rural_assist) as sum_rural_assist, avg(rural_assist) as avg_rural_assist, median(rural_assist) as mid_rural_assist,stddev(rural_assist) as std_rural_assist, max(rural_assist) as max_rural_assist,
# sum(available) as sum_available, avg(available) as avg_available, median(available) as mid_available,stddev(available) as std_available, max(available) as max_available,
# sum(personal_med_insurance) as sum_personal_med_insurance, avg(personal_med_insurance) as avg_personal_med_insurance, median(personal_med_insurance) as mid_personal_med_insurance,stddev(personal_med_insurance) as std_personal_med_insurance, max(personal_med_insurance) as max_personal_med_insurance,
# sum(non_account) as sum_non_account, avg(non_account) as avg_non_account, median(non_account) as mid_non_account,stddev(non_account) as std_non_account, max(non_account) as max_non_account,
# sum(approve) as sum_approve, avg(approve) as avg_approve, median(approve) as mid_approve,stddev(approve) as std_approve, max(approve) as max_approve,
# sum(assist_approve) as sum_assist_approve, avg(assist_approve) as avg_assist_approve, median(assist_approve) as mid_assist_approve,stddev(assist_approve) as std_assist_approve, max(assist_approve) as max_assist_approve,
# sum(med_assist_declare) as sum_med_assist_declare, avg(med_assist_declare) as avg_med_assist_declare, median(med_assist_declare) as mid_med_assist_declare,stddev(med_assist_declare) as std_med_assist_declare, max(med_assist_declare) as max_med_assist_declare,
# sum(disable_med_assist) as sum_disable_med_assist, avg(disable_med_assist) as avg_disable_med_assist, median(disable_med_assist) as mid_disable_med_assist,stddev(disable_med_assist) as std_disable_med_assist, max(disable_med_assist) as max_disable_med_assist,
# sum(gov_med_assist) as sum_gov_med_assist, avg(gov_med_assist) as avg_gov_med_assist, median(gov_med_assist) as mid_gov_med_assist,stddev(gov_med_assist) as std_gov_med_assist, max(gov_med_assist) as max_gov_med_assist,
# sum(rural_assist2) as sum_rural_assist2, avg(rural_assist2) as avg_rural_assist2, median(rural_assist2) as mid_rural_assist2,stddev(rural_assist2) as std_rural_assist2, max(rural_assist2) as max_rural_assist2,

# %% [markdown]
# # 重要诊断病种

# %%
("feat_disease_selected.csv")
("feat_service_selected.csv")
("feat_period_selected.csv")
("feat_trans_hospital_selected.csv")
("feat_to_hospital_selected.csv")

# %%
disease_list = []
for line in open("feat_disease_selected.csv","r"):
    disease_list.append(line.split(",")[1].strip())
for i,disease in enumerate(disease_list[1:]):
    print 'sum(disease regexp "{}") as disease_type_{},'.format(disease,i+1)
# Out:
# sum(disease regexp "不耐受") as disease_type_1,
# sum(disease regexp "中药止痛") as disease_type_2,
# sum(disease regexp "中风") as disease_type_3,
# sum(disease regexp "中风病") as disease_type_4,
# sum(disease regexp "乳腺恶性肿瘤") as disease_type_5,
# sum(disease regexp "乳腺癌") as disease_type_6,
# sum(disease regexp "伴有多个并发症的") as disease_type_7,
# sum(disease regexp "低蛋白血症") as disease_type_8,
# sum(disease regexp "偏瘫") as disease_type_9,
# sum(disease regexp "免疫力低下") as disease_type_10,
# sum(disease regexp "免疫功能低下") as disease_type_11,
# sum(disease regexp "免疫功能障碍") as disease_type_12,
# sum(disease regexp "冠心病") as disease_type_13,
# sum(disease regexp "冠状动脉性心脏病") as disease_type_14,
# sum(disease regexp "冠状动脉粥样硬化性心脏病") as disease_type_15,
# sum(disease regexp "动脉硬化性心脏病") as disease_type_16,
# sum(disease regexp "反复低血糖血糖不稳定") as disease_type_17,
# sum(disease regexp "反复发作低血糖") as disease_type_18,
# sum(disease regexp "否认癫痫") as disease_type_19,
# sum(disease regexp "否认药物过敏否认癫痫") as disease_type_20,
# sum(disease regexp "周围神经病") as disease_type_21,
# sum(disease regexp "周围神经病变") as disease_type_22,
# sum(disease regexp "周围血管神经病变") as disease_type_23,
# sum(disease regexp "哮喘") as disease_type_24,
# sum(disease regexp "型糖尿病") as disease_type_25,
# sum(disease regexp "型糖尿病反复严重低血糖") as disease_type_26,
# sum(disease regexp "型糖尿病性周围神经病") as disease_type_27,
# sum(disease regexp "型糖尿病性周围神经病变") as disease_type_28,
# sum(disease regexp "型糖尿病性周围血管病") as disease_type_29,
# sum(disease regexp "型糖尿病性视网膜病变") as disease_type_30,
# sum(disease regexp "失眠") as disease_type_31,
# sum(disease regexp "尿毒症") as disease_type_32,
# sum(disease regexp "微循环障碍") as disease_type_33,
# sum(disease regexp "微血管病变") as disease_type_34,
# sum(disease regexp "心律失常") as disease_type_35,
# sum(disease regexp "心肌缺血") as disease_type_36,
# sum(disease regexp "恶性高血压") as disease_type_37,
# sum(disease regexp "慢性动脉闭塞症") as disease_type_38,
# sum(disease regexp "慢性支气管炎") as disease_type_39,
# sum(disease regexp "慢性支气管炎合并肺部感染") as disease_type_40,
# sum(disease regexp "慢性肺源性心脏病") as disease_type_41,
# sum(disease regexp "慢性肾功能不全") as disease_type_42,
# sum(disease regexp "慢性肾功能衰竭") as disease_type_43,
# sum(disease regexp "慢性肾衰") as disease_type_44,
# sum(disease regexp "慢性肾衰竭") as disease_type_45,
# sum(disease regexp "慢性阻塞性肺疾病") as disease_type_46,
# sum(disease regexp "抑郁症") as disease_type_47,
# sum(disease regexp "挂号") as disease_type_48,
# sum(disease regexp "支气管炎") as disease_type_49,
# sum(disease regexp "晚期乳腺癌") as disease_type_50,
# sum(disease regexp "有严重并发症的糖尿病") as disease_type_51,
# sum(disease regexp "未知") as disease_type_52,
# sum(disease regexp "气虚血瘀") as disease_type_53,
# sum(disease regexp "消化不良") as disease_type_54,
# sum(disease regexp "消渴") as disease_type_55,
# sum(disease regexp "消渴病") as disease_type_56,
# sum(disease regexp "癌性疼痛") as disease_type_57,
# sum(disease regexp "癌症放化疗") as disease_type_58,
# sum(disease regexp "白细胞减少症") as disease_type_59,
# sum(disease regexp "睡眠障碍") as disease_type_60,
# sum(disease regexp "精神病") as disease_type_61,
# sum(disease regexp "精神障碍") as disease_type_62,
# sum(disease regexp "糖尿病") as disease_type_63,
# sum(disease regexp "糖尿病伴周围循环并发症") as disease_type_64,
# sum(disease regexp "糖尿病伴神经并发症") as disease_type_65,
# sum(disease regexp "糖尿病合并冠心病") as disease_type_66,
# sum(disease regexp "糖尿病合并微循环障碍") as disease_type_67,
# sum(disease regexp "糖尿病合并微血管病变") as disease_type_68,
# sum(disease regexp "糖尿病合并肾病") as disease_type_69,
# sum(disease regexp "糖尿病周围神经病变") as disease_type_70,
# sum(disease regexp "糖尿病周围血管病变") as disease_type_71,
# sum(disease regexp "糖尿病并肾病变") as disease_type_72,
# sum(disease regexp "糖尿病微循环障碍") as disease_type_73,
# sum(disease regexp "糖尿病微血管病变") as disease_type_74,
# sum(disease regexp "糖尿病性冠心病") as disease_type_75,
# sum(disease regexp "糖尿病性周围神经病") as disease_type_76,
# sum(disease regexp "糖尿病性周围神经病变") as disease_type_77,
# sum(disease regexp "糖尿病性周围血管病") as disease_type_78,
# sum(disease regexp "糖尿病性周围血管病变") as disease_type_79,
# sum(disease regexp "糖尿病性心脏病") as disease_type_80,
# sum(disease regexp "糖尿病性神经病变") as disease_type_81,
# sum(disease regexp "糖尿病性肾病") as disease_type_82,
# sum(disease regexp "糖尿病性视网膜病") as disease_type_83,
# sum(disease regexp "糖尿病眼底病变") as disease_type_84,
# sum(disease regexp "糖尿病神经病变") as disease_type_85,
# sum(disease regexp "糖尿病糖尿病合并微循环障碍") as disease_type_86,
# sum(disease regexp "糖尿病糖尿病性周围血管病") as disease_type_87,
# sum(disease regexp "糖尿病糖尿病肾病") as disease_type_88,
# sum(disease regexp "糖尿病肾病") as disease_type_89,
# sum(disease regexp "糖尿病血糖不稳定") as disease_type_90,
# sum(disease regexp "糖尿病血糖不稳定的糖尿病患者") as disease_type_91,
# sum(disease regexp "糖尿病视网膜病") as disease_type_92,
# sum(disease regexp "糖尿病视网膜病变") as disease_type_93,
# sum(disease regexp "糖尿病视网膜眼底病变") as disease_type_94,
# sum(disease regexp "糖尿病足") as disease_type_95,
# sum(disease regexp "糖尿病门特") as disease_type_96,
# sum(disease regexp "细菌感染") as disease_type_97,
# sum(disease regexp "肝功能不全") as disease_type_98,
# sum(disease regexp "肝功能异常") as disease_type_99,
# sum(disease regexp "肝损害") as disease_type_100,
# sum(disease regexp "肺原性心脏病") as disease_type_101,
# sum(disease regexp "肺心病") as disease_type_102,
# sum(disease regexp "肺心病一线无效二线用药") as disease_type_103,
# sum(disease regexp "肺恶性肿瘤") as disease_type_104,
# sum(disease regexp "肺感染") as disease_type_105,
# sum(disease regexp "肺源性心脏病") as disease_type_106,
# sum(disease regexp "肺炎") as disease_type_107,
# sum(disease regexp "肺癌") as disease_type_108,
# sum(disease regexp "肺纤维化") as disease_type_109,
# sum(disease regexp "肾功能不全") as disease_type_110,
# sum(disease regexp "肾功能衰竭") as disease_type_111,
# sum(disease regexp "肾性贫血") as disease_type_112,
# sum(disease regexp "肾性骨病") as disease_type_113,
# sum(disease regexp "肾性高血压") as disease_type_114,
# sum(disease regexp "肾性高血压伴高血压性心脏病") as disease_type_115,
# sum(disease regexp "肾病") as disease_type_116,
# sum(disease regexp "肾移植术后") as disease_type_117,
# sum(disease regexp "肾移植术后复查") as disease_type_118,
# sum(disease regexp "肾透析") as disease_type_119,
# sum(disease regexp "胃炎") as disease_type_120,
# sum(disease regexp "脆性") as disease_type_121,
# sum(disease regexp "脆性糖尿病") as disease_type_122,
# sum(disease regexp "脑供血不足") as disease_type_123,
# sum(disease regexp "脑卒中") as disease_type_124,
# sum(disease regexp "脑梗塞") as disease_type_125,
# sum(disease regexp "脑梗塞偏瘫") as disease_type_126,
# sum(disease regexp "脑梗塞后遗症") as disease_type_127,
# sum(disease regexp "脑梗死") as disease_type_128,
# sum(disease regexp "脑梗死后遗症") as disease_type_129,
# sum(disease regexp "腹膜透析") as disease_type_130,
# sum(disease regexp "血管病变") as disease_type_131,
# sum(disease regexp "血管紧张素转换酶抑制剂不耐受") as disease_type_132,
# sum(disease regexp "血糖不稳定") as disease_type_133,
# sum(disease regexp "血糖不稳定的糖尿病") as disease_type_134,
# sum(disease regexp "血糖不稳定糖尿病") as disease_type_135,
# sum(disease regexp "视网膜病变") as disease_type_136,
# sum(disease regexp "贫血") as disease_type_137,
# sum(disease regexp "过敏性鼻炎") as disease_type_138,
# sum(disease regexp "重症高血压") as disease_type_139,
# sum(disease regexp "门特") as disease_type_140,
# sum(disease regexp "门特挂号") as disease_type_141,
# sum(disease regexp "非胰岛素依赖Ⅱ型糖尿病") as disease_type_142,
# sum(disease regexp "骨质疏松") as disease_type_143,
# sum(disease regexp "骨髓抑制") as disease_type_144,
# sum(disease regexp "高粘血症") as disease_type_145,
# sum(disease regexp "高胆固醇血症") as disease_type_146,
# sum(disease regexp "高脂血症") as disease_type_147,
# sum(disease regexp "高血压") as disease_type_148,
# sum(disease regexp "高血压Ⅱ") as disease_type_149,
# sum(disease regexp "高血压Ⅲ") as disease_type_150,
# sum(disease regexp "高血压病") as disease_type_151,
# sum(disease regexp "高血脂") as disease_type_152,

# %% [markdown]
# # 重要三目

# %%
service_list = []
for line in open("feat_service_selected.csv","r"):
    service_list.append(line.split(",")[1].strip())
for i,service in enumerate(service_list[1:]):
    print 'sum(service1 regexp "{}" or service2 regexp "{}") as service_type_{},'.format(service,service,i+1)
# Out:
# sum(service1 regexp "一次性连轴式止血带（压力绷带）2 0 35CM" or service2 regexp "一次性连轴式止血带（压力绷带）2 0 35CM") as service_type_1,
# sum(service1 regexp "三级医院" or service2 regexp "三级医院") as service_type_2,
# sum(service1 regexp "丙肝抗体（酶免法）" or service2 regexp "丙肝抗体（酶免法）") as service_type_3,
# sum(service1 regexp "丹芪偏瘫胶囊" or service2 regexp "丹芪偏瘫胶囊") as service_type_4,
# sum(service1 regexp "主任医师挂号费" or service2 regexp "主任医师挂号费") as service_type_5,
# sum(service1 regexp "乙型肝炎e抗体测定" or service2 regexp "乙型肝炎e抗体测定") as service_type_6,
# sum(service1 regexp "乙型肝炎e抗原测定" or service2 regexp "乙型肝炎e抗原测定") as service_type_7,
# sum(service1 regexp "乙型肝炎核心抗体测定" or service2 regexp "乙型肝炎核心抗体测定") as service_type_8,
# sum(service1 regexp "乙型肝炎表面抗体测定" or service2 regexp "乙型肝炎表面抗体测定") as service_type_9,
# sum(service1 regexp "乙型肝炎表面抗原测定" or service2 regexp "乙型肝炎表面抗原测定") as service_type_10,
# sum(service1 regexp "乙肝e抗体（免疫）" or service2 regexp "乙肝e抗体（免疫）") as service_type_11,
# sum(service1 regexp "乙肝e抗原（免疫）" or service2 regexp "乙肝e抗原（免疫）") as service_type_12,
# sum(service1 regexp "乙肝核心抗体" or service2 regexp "乙肝核心抗体") as service_type_13,
# sum(service1 regexp "乙肝表面抗体（免疫）" or service2 regexp "乙肝表面抗体（免疫）") as service_type_14,
# sum(service1 regexp "乙肝表面抗原（免疫）" or service2 regexp "乙肝表面抗原（免疫）") as service_type_15,
# sum(service1 regexp "低分子肝素钠注射液" or service2 regexp "低分子肝素钠注射液") as service_type_16,
# sum(service1 regexp "低分子量肝素钙注射液" or service2 regexp "低分子量肝素钙注射液") as service_type_17,
# sum(service1 regexp "低分子量肝素钠注射液" or service2 regexp "低分子量肝素钠注射液") as service_type_18,
# sum(service1 regexp "依诺肝素钠注射液" or service2 regexp "依诺肝素钠注射液") as service_type_19,
# sum(service1 regexp "副主任医师挂号费" or service2 regexp "副主任医师挂号费") as service_type_20,
# sum(service1 regexp "参松养心胶囊" or service2 regexp "参松养心胶囊") as service_type_21,
# sum(service1 regexp "地奥心血康软胶囊" or service2 regexp "地奥心血康软胶囊") as service_type_22,
# sum(service1 regexp "多导心电图" or service2 regexp "多导心电图") as service_type_23,
# sum(service1 regexp "多导心电图检查自动分析" or service2 regexp "多导心电图检查自动分析") as service_type_24,
# sum(service1 regexp "尿沉渣离心显微镜检查（门特）" or service2 regexp "尿沉渣离心显微镜检查（门特）") as service_type_25,
# sum(service1 regexp "挂号" or service2 regexp "挂号") as service_type_26,
# sum(service1 regexp "未知" or service2 regexp "未知") as service_type_27,
# sum(service1 regexp "注射用低分子量肝素钠" or service2 regexp "注射用低分子量肝素钠") as service_type_28,
# sum(service1 regexp "清肺消炎丸" or service2 regexp "清肺消炎丸") as service_type_29,
# sum(service1 regexp "牛黄清心丸" or service2 regexp "牛黄清心丸") as service_type_30,
# sum(service1 regexp "病床紫外线消毒" or service2 regexp "病床紫外线消毒") as service_type_31,
# sum(service1 regexp "癌胚抗原（微粒子化学发光法）" or service2 regexp "癌胚抗原（微粒子化学发光法）") as service_type_32,
# sum(service1 regexp "癌胚抗原（电化学发光法）" or service2 regexp "癌胚抗原（电化学发光法）") as service_type_33,
# sum(service1 regexp "稳心颗粒" or service2 regexp "稳心颗粒") as service_type_34,
# sum(service1 regexp "糖尿病门诊诊察费（门特加收）" or service2 regexp "糖尿病门诊诊察费（门特加收）") as service_type_35,
# sum(service1 regexp "肝功能及肝血流测定" or service2 regexp "肝功能及肝血流测定") as service_type_36,
# sum(service1 regexp "肝素钠注射液" or service2 regexp "肝素钠注射液") as service_type_37,
# sum(service1 regexp "肺力咳合剂" or service2 regexp "肺力咳合剂") as service_type_38,
# sum(service1 regexp "肺力咳胶囊" or service2 regexp "肺力咳胶囊") as service_type_39,
# sum(service1 regexp "肾小球滤过率（肌酐）" or service2 regexp "肾小球滤过率（肌酐）") as service_type_40,
# sum(service1 regexp "肾炎康复片" or service2 regexp "肾炎康复片") as service_type_41,
# sum(service1 regexp "脑心通胶囊" or service2 regexp "脑心通胶囊") as service_type_42,
# sum(service1 regexp "莲子心" or service2 regexp "莲子心") as service_type_43,
# sum(service1 regexp "血栓心脉宁片" or service2 regexp "血栓心脉宁片") as service_type_44,
# sum(service1 regexp "负压采血管" or service2 regexp "负压采血管") as service_type_45,
# sum(service1 regexp "通心络胶囊" or service2 regexp "通心络胶囊") as service_type_46,
# sum(service1 regexp "通脉养心丸" or service2 regexp "通脉养心丸") as service_type_47,
# sum(service1 regexp "速效救心丸" or service2 regexp "速效救心丸") as service_type_48,
# sum(service1 regexp "高压注射针筒 200" or service2 regexp "高压注射针筒 200") as service_type_49,
# sum(service1 regexp "鳞状细胞癌相关抗原测定（scc）" or service2 regexp "鳞状细胞癌相关抗原测定（scc）") as service_type_50,
# sum(service1 regexp "麝香保心丸" or service2 regexp "麝香保心丸") as service_type_51,

# %% [markdown]
# # 重要交易医院

# %%
hospital_list = []
for line in open("feat_trans_hospital_selected.csv","r"):
    hospital_list.append(line.split(",")[1].strip())
for i,hospital in enumerate(hospital_list):
    print 'sum(hip={}) as trans_hip_{},'.format(hospital,hospital)
# Out:
# sum(hip=102) as trans_hip_102,
# sum(hip=104) as trans_hip_104,
# sum(hip=105) as trans_hip_105,
# sum(hip=1058) as trans_hip_1058,
# sum(hip=1068) as trans_hip_1068,
# sum(hip=107) as trans_hip_107,
# sum(hip=1072) as trans_hip_1072,
# sum(hip=1079) as trans_hip_1079,
# sum(hip=110) as trans_hip_110,
# sum(hip=111) as trans_hip_111,
# sum(hip=1129) as trans_hip_1129,
# sum(hip=115) as trans_hip_115,
# sum(hip=122) as trans_hip_122,
# sum(hip=125) as trans_hip_125,
# sum(hip=1254) as trans_hip_1254,
# sum(hip=126) as trans_hip_126,
# sum(hip=127) as trans_hip_127,
# sum(hip=135) as trans_hip_135,
# sum(hip=136) as trans_hip_136,
# sum(hip=139) as trans_hip_139,
# sum(hip=140) as trans_hip_140,
# sum(hip=141) as trans_hip_141,
# sum(hip=143) as trans_hip_143,
# sum(hip=1431) as trans_hip_1431,
# sum(hip=144) as trans_hip_144,
# sum(hip=145) as trans_hip_145,
# sum(hip=1468) as trans_hip_1468,
# sum(hip=149) as trans_hip_149,
# sum(hip=150) as trans_hip_150,
# sum(hip=153) as trans_hip_153,
# sum(hip=154) as trans_hip_154,
# sum(hip=155) as trans_hip_155,
# sum(hip=158) as trans_hip_158,
# sum(hip=159) as trans_hip_159,
# sum(hip=160) as trans_hip_160,
# sum(hip=161) as trans_hip_161,
# sum(hip=170) as trans_hip_170,
# sum(hip=173) as trans_hip_173,
# sum(hip=177) as trans_hip_177,
# sum(hip=178) as trans_hip_178,
# sum(hip=180) as trans_hip_180,
# sum(hip=182) as trans_hip_182,
# sum(hip=183) as trans_hip_183,
# sum(hip=184) as trans_hip_184,
# sum(hip=185) as trans_hip_185,
# sum(hip=186) as trans_hip_186,
# sum(hip=188) as trans_hip_188,
# sum(hip=189) as trans_hip_189,
# sum(hip=190) as trans_hip_190,
# sum(hip=192) as trans_hip_192,
# sum(hip=193) as trans_hip_193,
# sum(hip=194) as trans_hip_194,
# sum(hip=195) as trans_hip_195,
# sum(hip=196) as trans_hip_196,
# sum(hip=197) as trans_hip_197,
# sum(hip=201) as trans_hip_201,
# sum(hip=24) as trans_hip_24,
# sum(hip=30) as trans_hip_30,
# sum(hip=32) as trans_hip_32,
# sum(hip=34) as trans_hip_34,
# sum(hip=42) as trans_hip_42,
# sum(hip=44) as trans_hip_44,
# sum(hip=444) as trans_hip_444,
# sum(hip=449) as trans_hip_449,
# sum(hip=482) as trans_hip_482,
# sum(hip=5) as trans_hip_5,
# sum(hip=558) as trans_hip_558,
# sum(hip=559) as trans_hip_559,
# sum(hip=567) as trans_hip_567,
# sum(hip=571) as trans_hip_571,
# sum(hip=587) as trans_hip_587,
# sum(hip=613) as trans_hip_613,
# sum(hip=626) as trans_hip_626,
# sum(hip=65) as trans_hip_65,
# sum(hip=69) as trans_hip_69,
# sum(hip=7) as trans_hip_7,
# sum(hip=704) as trans_hip_704,
# sum(hip=723) as trans_hip_723,
# sum(hip=74) as trans_hip_74,
# sum(hip=76) as trans_hip_76,
# sum(hip=77) as trans_hip_77,
# sum(hip=896) as trans_hip_896,
# sum(hip=934) as trans_hip_934,
# sum(hip=98) as trans_hip_98,

# %% [markdown]
# # 重要去的医院

# %%
hospital_list = []
for line in open("feat_to_hospital_selected.csv","r"):
    hospital_list.append(line.split(",")[1].strip())
for i,hospital in enumerate(hospital_list):
    print 'sum(hip={}) as to_hip_{},'.format(hospital,hospital)
# Out:
# sum(hip=102) as to_hip_102,
# sum(hip=104) as to_hip_104,
# sum(hip=1058) as to_hip_1058,
# sum(hip=1068) as to_hip_1068,
# sum(hip=1072) as to_hip_1072,
# sum(hip=1079) as to_hip_1079,
# sum(hip=111) as to_hip_111,
# sum(hip=115) as to_hip_115,
# sum(hip=122) as to_hip_122,
# sum(hip=125) as to_hip_125,
# sum(hip=1254) as to_hip_1254,
# sum(hip=126) as to_hip_126,
# sum(hip=127) as to_hip_127,
# sum(hip=135) as to_hip_135,
# sum(hip=136) as to_hip_136,
# sum(hip=139) as to_hip_139,
# sum(hip=140) as to_hip_140,
# sum(hip=141) as to_hip_141,
# sum(hip=143) as to_hip_143,
# sum(hip=1431) as to_hip_1431,
# sum(hip=145) as to_hip_145,
# sum(hip=149) as to_hip_149,
# sum(hip=150) as to_hip_150,
# sum(hip=153) as to_hip_153,
# sum(hip=154) as to_hip_154,
# sum(hip=159) as to_hip_159,
# sum(hip=160) as to_hip_160,
# sum(hip=161) as to_hip_161,
# sum(hip=170) as to_hip_170,
# sum(hip=173) as to_hip_173,
# sum(hip=177) as to_hip_177,
# sum(hip=178) as to_hip_178,
# sum(hip=180) as to_hip_180,
# sum(hip=182) as to_hip_182,
# sum(hip=183) as to_hip_183,
# sum(hip=184) as to_hip_184,
# sum(hip=185) as to_hip_185,
# sum(hip=188) as to_hip_188,
# sum(hip=189) as to_hip_189,
# sum(hip=190) as to_hip_190,
# sum(hip=192) as to_hip_192,
# sum(hip=193) as to_hip_193,
# sum(hip=194) as to_hip_194,
# sum(hip=195) as to_hip_195,
# sum(hip=196) as to_hip_196,
# sum(hip=197) as to_hip_197,
# sum(hip=201) as to_hip_201,
# sum(hip=24) as to_hip_24,
# sum(hip=30) as to_hip_30,
# sum(hip=32) as to_hip_32,
# sum(hip=34) as to_hip_34,
# sum(hip=42) as to_hip_42,
# sum(hip=43) as to_hip_43,
# sum(hip=44) as to_hip_44,
# sum(hip=444) as to_hip_444,
# sum(hip=449) as to_hip_449,
# sum(hip=482) as to_hip_482,
# sum(hip=5) as to_hip_5,
# sum(hip=51) as to_hip_51,
# sum(hip=558) as to_hip_558,
# sum(hip=559) as to_hip_559,
# sum(hip=567) as to_hip_567,
# sum(hip=569) as to_hip_569,
# sum(hip=571) as to_hip_571,
# sum(hip=587) as to_hip_587,
# sum(hip=596) as to_hip_596,
# sum(hip=626) as to_hip_626,
# sum(hip=65) as to_hip_65,
# sum(hip=69) as to_hip_69,
# sum(hip=7) as to_hip_7,
# sum(hip=723) as to_hip_723,
# sum(hip=74) as to_hip_74,
# sum(hip=76) as to_hip_76,
# sum(hip=766) as to_hip_766,
# sum(hip=77) as to_hip_77,
# sum(hip=896) as to_hip_896,
# sum(hip=934) as to_hip_934,
# sum(hip=98) as to_hip_98,

# %% [markdown]
# # 时间间隔特征

# %%
period_list = []
for line in open("feat_period_selected.csv","r"):
    period_list.append(line.split(",")[1].strip())
for i,period in enumerate(period_list):
    print i,period
# Out:
# 0 every_ave_period
# 1 every_max_period
# 2 every_min_period
# 3 every_period_0
# 4 every_period_1
# 5 every_period_10
# 6 every_period_11
# 7 every_period_12
# 8 every_period_13
# 9 every_period_14
# 10 every_period_15
# 11 every_period_16
# 12 every_period_17
# 13 every_period_18
# 14 every_period_19
# 15 every_period_2
# 16 every_period_20
# 17 every_period_21
# 18 every_period_22
# 19 every_period_23
# 20 every_period_24
# 21 every_period_25
# 22 every_period_27
# 23 every_period_28
# 24 every_period_29
# 25 every_period_3
# 26 every_period_30
# 27 every_period_31
# 28 every_period_32
# 29 every_period_34
# 30 every_period_37
# 31 every_period_38
# 32 every_period_4
# 33 every_period_40
# 34 every_period_42
# 35 every_period_5
# 36 every_period_6
# 37 every_period_7
# 38 every_period_8
# 39 every_period_9
# 40 every_q1_period
# 41 every_q2_period
# 42 every_q3_period

# %%
import pandas as pd
feat_period =pd.read_csv("feat_period_selected_imp.csv",header=None,index_col=0)

# %%
feat_period
# Out:
#                          1
# 0
# every_ave_period  0.012058
# every_q3_period   0.010170
# every_max_period  0.008537
# every_period_2    0.006817
# every_period_1    0.006011
# every_period_0    0.003764
# every_q1_period   0.003158
# every_period_3    0.003053
# every_q2_period   0.002702
# every_period_4    0.002277
# every_period_7    0.001611
# every_period_19   0.001603
# every_min_period  0.001589
# every_period_24   0.001521
# every_period_5    0.001383
# every_period_14   0.001353
# every_period_16   0.001318
# every_period_17   0.000996
# every_period_6    0.000960
# every_period_22   0.000892
# every_period_9    0.000826
# every_period_18   0.000760
# every_period_13   0.000758
# every_period_8    0.000734
# every_period_11   0.000709
# every_period_12   0.000605
# every_period_38   0.000600
# every_period_10   0.000387
# every_period_15   0.000319
# every_period_23   0.000314
# every_period_28   0.000215
# every_period_37   0.000151
# every_period_21   0.000130
# every_period_27   0.000120
# every_period_20   0.000106
# every_period_29   0.000069
# every_period_42   0.000055
# every_period_30   0.000054
# every_period_31   0.000035
# every_period_40   0.000024
# every_period_32   0.000011
# every_period_25   0.000008
# every_period_34   0.000007
