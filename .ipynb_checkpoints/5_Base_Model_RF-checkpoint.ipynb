# %% [markdown]
# # Import libraries

# %%
# Import libraries:
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn import cross_validation, metrics
from sklearn.grid_search import GridSearchCV

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12,4

# 为显示中文
from pylab import *  
mpl.rcParams['font.sans-serif'] = ['SimHei']
# Out:
# D:\Program Files\Anaconda\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\Program Files\Anaconda\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ## Load data

# %%
# all the features with target
df_train_test = pd.read_csv("total_feat_train.csv",index_col="个人编码")
# 所有特征
features = df_train_test.columns.difference(['target'])

# %%
model1_feat = pd.read_csv("model1_features.csv",index_col=0).index.unique()
model1_feat_apply = pd.read_csv("model1_feat_imp.csv",index_col=0,header=None).index
model2_feat = pd.read_csv("model2_features.csv",header=None).set_index(1).index.unique()
model2_feat_apply = pd.read_csv("model2_feat_imp.csv",index_col=0,header=None).index
predictors = model1_feat.union(model2_feat)

# %%
# 去除重复特征
def duplicate_columns(frame):
    groups = frame.columns.to_series().groupby(frame.dtypes).groups
    dups = []
    for t, v in groups.items():
        dcols = frame[v].to_dict(orient="list")

        vs = dcols.values()
        ks = dcols.keys()
        lvs = len(vs)

        for i in range(lvs):
            for j in range(i+1,lvs):
                if vs[i] == vs[j]: 
                    dups.append(ks[i])
                    break

    return dups

dups = duplicate_columns(df_train_test[predictors])

# %% [markdown]
# ### Predictors

# %%
predictors = predictors.difference(dups)
predictors = predictors.difference(["first_time"])

# Using the 3000+features?
#dups = duplicate_columns(df_train_test[features])
#predictors = features.difference(dups)
                                       
target = 'target'

# %%
predictorsictors.size
# Out:
# 3579

# %%
df_train_test['target'].value_counts()
# Out:
# 0    19000
# 1     1000
# Name: target, dtype: int64

# %% [markdown]
# ## Spliting training and testing set

# %%
from sklearn.model_selection import StratifiedShuffleSplit
ss = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=0)
idx_train, idx_test = ss.split(df_train_test[predictors],df_train_test[target]).next()
print 'train: ',len(idx_train)
print 'test: ',len(idx_test)
print 'ratio',float(len(idx_test))/(len(idx_train)+len(idx_test))
# Out:
# train:  16000
# test:  4000
# ratio 0.2

# %%
df_train = df_train_test.iloc[idx_train,:]
df_test = df_train_test.iloc[idx_test,:]

# %% [markdown]
# ## Define a function for modeling and cross-validation

# %%
def modelfit(alg, dtrain, dtest, predictors, useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    '''  '''
    if useTrainCV:  # 使用交叉验证选取最佳树棵树
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'],\
                          nfold=cv_folds,metrics='auc',early_stopping_rounds=early_stopping_rounds,verbose_eval=10)
        alg.set_params(n_estimators=cvresult.shape[0])

        
    # fit the algorithm on the data:
    alg.fit(dtrain[predictors], dtrain[target],eval_metric='auc')
    
    # predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
    
    # print model report:
    print "\nModel Report"
    print 'n_estimators: ',cvresult.shape[0]
    print "Training:"
    print "Accuracy : %.4g" % metrics.accuracy_score(dtrain[target], dtrain_predictions)
    print "F1 Score : %f" % metrics.f1_score(dtrain[target],dtrain_predictions)
    print "AUC Score (Train): %f" % metrics.roc_auc_score(dtrain[target],dtrain_predprob)
    print "Classification Report : \n", metrics.classification_report(dtrain[target],dtrain_predictions)
    print ""
    
    # predict on testing data:
    print "Testing: "
    dtest_predictions = alg.predict(dtest[predictors])
    dtest_predprob = alg.predict_proba(dtest[predictors])[:,1]
    #results = test_results.merge(dtest[['ID','predprob']], on='ID')
    print "Accuracy : %.4g" % metrics.accuracy_score(dtest[target], dtest_predictions)
    print "F1 Score : %f" % metrics.f1_score(dtest[target],dtest_predictions)
    print 'AUC Score (Test): %f' % metrics.roc_auc_score(dtest[target], dtest_predprob)
    print "Classification Report : \n", metrics.classification_report(dtest[target],dtest_predictions)
    
    feat_imp = pd.Series(alg.booster().get_fscore()).sort_values(ascending=False)
    feat_imp[0:60].plot(kind='bar', title='Feature Importance')
    plt.ylabel('Feature Importance Score')
    
    return feat_imp

# %% [markdown]
# ## Step 1-Find the number of estimators for a high learning rate
# **General Approach for Parameter Tuning**
# - **step 1**: 选择一个相对较大的学习率learning_rate. 通常选取0.1，或者在0.05-0.3间. 在给定学习率下，通过xgboost提供的cv函数确定最优的树的数量
# - **step 2**: 在给定学习率，数的棵树下，调节关于树的参数(max_depth, min_child_weight, gamma, subsample, colsample_bytree)
# - **step 3**：然后，调节正则化参数(lambda,alpha),以减小模型复杂度、提高性能
# - **step 4**：减小学习率，确定最优参数

# %%
# choose all predictors except target & IDcols
# predictors = [x for x in train.columns if x not in [target]]
rf = RandomForestClassifier()
rf.fit(df_train[predictors],df_train[target])
# Out:
# [0]	train-auc:0.800652+0.00731002	test-auc:0.779583+0.0298053
# [10]	train-auc:0.902451+0.00383443	test-auc:0.862948+0.0217651
# [20]	train-auc:0.934538+0.00231668	test-auc:0.882192+0.0145361
# [30]	train-auc:0.95623+0.00177219	test-auc:0.897979+0.00457255
# [40]	train-auc:0.972572+0.00140319	test-auc:0.905536+0.00667392
# [50]	train-auc:0.981937+0.000355999	test-auc:0.909702+0.00695669
# [60]	train-auc:0.9878+0.000666016	test-auc:0.910072+0.0086476
# [70]	train-auc:0.99152+0.00042089	test-auc:0.911156+0.0078225
# [80]	train-auc:0.994471+0.000454433	test-auc:0.911031+0.00779783
# [90]	train-auc:0.996396+0.000297921	test-auc:0.911783+0.008468
# [100]	train-auc:0.997594+0.000288766	test-auc:0.912256+0.00846835
# [110]	train-auc:0.998491+0.000208293	test-auc:0.912492+0.00796772
# [120]	train-auc:0.999044+0.000226041	test-auc:0.912267+0.00762724
# [130]	train-auc:0.999418+0.000131415	test-auc:0.912334+0.00722381
# [140]	train-auc:0.999659+0.000111728	test-auc:0.912119+0.00681332
# [150]	train-auc:0.999799+8.15735e-05	test-auc:0.912004+0.00724241
# [160]	train-auc:0.999897+4.42764e-05	test-auc:0.911754+0.00688289
# [170]	train-auc:0.99995+2.57263e-05	test-auc:0.911102+0.0064187
# [180]	train-auc:0.999981+1.08701e-05	test-auc:0.91083+0.00654146
#
# Model Report
# n_estimators:  136
# Training:
# Accuracy : 0.9874
# F1 Score : 0.855508
# AUC Score (Train): 0.998810
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99     15200
#           1       1.00      0.75      0.86       800
#
# avg / total       0.99      0.99      0.99     16000
#
#
# Testing:
# Accuracy : 0.9637
# F1 Score : 0.487633
# AUC Score (Test): 0.925046
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      3800
#           1       0.83      0.34      0.49       200
#
# avg / total       0.96      0.96      0.96      4000

# %%
feat_imp[-60:].plot(kind='bar')

# %% [markdown]
# ## step 2-Tune max_depth and min_child_weight

# %%
#Grid seach on subsample and max_features
#Choose all predictors except target & IDcols
param_test1 = {
    'max_depth':range(3,10,2),
    'min_child_weight':range(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=136, max_depth=5,
                                        min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
                                        objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27), 
                       param_grid = param_test1, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch1.fit(df_train[predictors],df_train[target])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=136, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'max_depth': [3, 5, 7, 9], 'min_child_weight': [1, 3, 5]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=0)

# %%
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# ([mean: 0.90721, std: 0.01047, params: {'max_depth': 3, 'min_child_weight': 1},
#   mean: 0.90818, std: 0.01371, params: {'max_depth': 3, 'min_child_weight': 3},
#   mean: 0.90855, std: 0.01118, params: {'max_depth': 3, 'min_child_weight': 5},
#   mean: 0.91390, std: 0.01029, params: {'max_depth': 5, 'min_child_weight': 1},
#   mean: 0.91285, std: 0.01080, params: {'max_depth': 5, 'min_child_weight': 3},
#   mean: 0.91264, std: 0.01115, params: {'max_depth': 5, 'min_child_weight': 5},
#   mean: 0.91143, std: 0.01285, params: {'max_depth': 7, 'min_child_weight': 1},
#   mean: 0.91070, std: 0.01158, params: {'max_depth': 7, 'min_child_weight': 3},
#   mean: 0.91353, std: 0.01280, params: {'max_depth': 7, 'min_child_weight': 5},
#   mean: 0.91283, std: 0.01309, params: {'max_depth': 9, 'min_child_weight': 1},
#   mean: 0.91233, std: 0.01033, params: {'max_depth': 9, 'min_child_weight': 3},
#   mean: 0.91146, std: 0.01351, params: {'max_depth': 9, 'min_child_weight': 5}],
#  {'max_depth': 5, 'min_child_weight': 1},
#  0.9139009046052632)

# %%
#Grid seach on subsample and max_features
#Choose all predictors except target & IDcols
param_test2 = {
    'max_depth':[4,5,6],
    'min_child_weight':[0.5,1,2]
}
gsearch2 = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=136, max_depth=5,
                                        min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.8,
                                        objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
                       param_grid = param_test2, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2.fit(df_train[predictors],df_train[target])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=2, missing=None, n_estimators=136, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'max_depth': [4, 5, 6], 'min_child_weight': [0.5, 1, 2]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=0)

# %%
gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# ([mean: 0.90893, std: 0.01252, params: {'max_depth': 4, 'min_child_weight': 0.5},
#   mean: 0.91043, std: 0.00902, params: {'max_depth': 4, 'min_child_weight': 1},
#   mean: 0.91033, std: 0.01075, params: {'max_depth': 4, 'min_child_weight': 2},
#   mean: 0.90997, std: 0.01365, params: {'max_depth': 5, 'min_child_weight': 0.5},
#   mean: 0.91390, std: 0.01029, params: {'max_depth': 5, 'min_child_weight': 1},
#   mean: 0.91345, std: 0.00937, params: {'max_depth': 5, 'min_child_weight': 2},
#   mean: 0.91079, std: 0.01185, params: {'max_depth': 6, 'min_child_weight': 0.5},
#   mean: 0.91265, std: 0.01113, params: {'max_depth': 6, 'min_child_weight': 1},
#   mean: 0.91435, std: 0.01083, params: {'max_depth': 6, 'min_child_weight': 2}],
#  {'max_depth': 6, 'min_child_weight': 2},
#  0.9143486842105263)

# %%
#Grid seach on subsample and max_features
#Choose all predictors except target & IDcols
param_test2b = {
    'max_depth':[6,7,8],
    'min_child_weight':[1,2,3]
}
gsearch2b = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=136, max_depth=5,
                                        min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.8,
                                        objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
                       param_grid = param_test2b, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch2b.fit(df_train[predictors],df_train[target])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=2, missing=None, n_estimators=136, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'max_depth': [6, 7, 8], 'min_child_weight': [1, 2, 3]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='roc_auc', verbose=0)

# %%
gsearch2b.grid_scores_, gsearch2b.best_params_, gsearch2b.best_score_
# Out:
# ([mean: 0.91265, std: 0.01113, params: {'max_depth': 6, 'min_child_weight': 1},
#   mean: 0.91435, std: 0.01083, params: {'max_depth': 6, 'min_child_weight': 2},
#   mean: 0.90959, std: 0.01089, params: {'max_depth': 6, 'min_child_weight': 3},
#   mean: 0.91143, std: 0.01285, params: {'max_depth': 7, 'min_child_weight': 1},
#   mean: 0.91406, std: 0.01214, params: {'max_depth': 7, 'min_child_weight': 2},
#   mean: 0.91070, std: 0.01158, params: {'max_depth': 7, 'min_child_weight': 3},
#   mean: 0.91317, std: 0.01349, params: {'max_depth': 8, 'min_child_weight': 1},
#   mean: 0.91195, std: 0.00953, params: {'max_depth': 8, 'min_child_weight': 2},
#   mean: 0.91229, std: 0.01145, params: {'max_depth': 8, 'min_child_weight': 3}],
#  {'max_depth': 6, 'min_child_weight': 2},
#  0.9143486842105263)

# %% [markdown]
# ## step 3-Tune gamma

# %%
#'gamma':[i/10.0 for i in range(0,2)]
param_test3 = {
 'gamma':[0,0.05,0.1]
}
gsearch3 = GridSearchCV(estimator = XGBClassifier( learning_rate=0.1, n_estimators=136, max_depth=6,
                                        min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.8,
                                        objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
                       param_grid = param_test3, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch3.fit(df_train[predictors],df_train[target])
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=6,
#        min_child_weight=2, missing=None, n_estimators=136, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=0.8),
#        fit_params={}, iid=False, n_jobs=4,
#        param_grid={'gamma': [0, 0.05, 0.1]}, pre_dispatch='2*n_jobs',
#        refit=True, scoring='roc_auc', verbose=0)

# %%
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# Out:
# ([mean: 0.91435, std: 0.01083, params: {'gamma': 0},
#   mean: 0.91246, std: 0.01196, params: {'gamma': 0.05},
#   mean: 0.91265, std: 0.01219, params: {'gamma': 0.1}],
#  {'gamma': 0},
#  0.9143486842105263)

# %%
# Re-calibrate the number of boosting rounds for the updated parameters
xgb2 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=6,
 min_child_weight=2,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.8,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb2, df_train, df_test,predictors)
# Out:
# [0]	train-auc:0.818341+0.00781009	test-auc:0.787051+0.0320436
# [10]	train-auc:0.921494+0.00615541	test-auc:0.87301+0.0196708
# [20]	train-auc:0.95127+0.00244846	test-auc:0.890442+0.0143965
# [30]	train-auc:0.969712+0.00195952	test-auc:0.900556+0.00850905
# [40]	train-auc:0.983953+0.000734182	test-auc:0.908404+0.00729674
# [50]	train-auc:0.991027+0.000889395	test-auc:0.909415+0.00810434
# [60]	train-auc:0.99486+0.000267138	test-auc:0.910313+0.00713528
# [70]	train-auc:0.996888+0.00051063	test-auc:0.910868+0.00693054
# [80]	train-auc:0.998341+0.00034023	test-auc:0.911992+0.00582669
# [90]	train-auc:0.999076+0.000201921	test-auc:0.912121+0.005095
# [100]	train-auc:0.999486+0.000139273	test-auc:0.911732+0.00510397
# [110]	train-auc:0.999724+7.42418e-05	test-auc:0.912118+0.005316
# [120]	train-auc:0.999865+4.8504e-05	test-auc:0.912045+0.00516099
# [130]	train-auc:0.999937+2.43014e-05	test-auc:0.912116+0.0057197
# [140]	train-auc:0.999971+1.92042e-05	test-auc:0.912142+0.00613942
# [150]	train-auc:0.999988+9.32523e-06	test-auc:0.911759+0.0062599
# [160]	train-auc:0.999997+3.05941e-06	test-auc:0.911724+0.00678737
# [170]	train-auc:0.999999+9.79796e-07	test-auc:0.911415+0.00615993
#
# Model Report
# n_estimators:  127
# Training:
# Accuracy : 0.9924
# F1 Score : 0.917456
# AUC Score (Train): 0.999559
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00     15200
#           1       1.00      0.85      0.92       800
#
# avg / total       0.99      0.99      0.99     16000
#
#
# Testing:
# Accuracy : 0.9655
# F1 Score : 0.520833
# AUC Score (Test): 0.920922
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      3800
#           1       0.85      0.38      0.52       200
#
# avg / total       0.96      0.97      0.96      4000
# trans_stat_sum          106
# every_ave_period         95
# total_period             75
# total_trans_rate         75
# last_time                62
# trans_stat_std           57
# 三目统计项目_sum               57
# every_q3_period          56
# 中成药费发生金额_max             53
# trans_stat_q3            49
# every_max_period         48
# 贵重药品发生金额_max             44
# num_total_hospitals      44
# trans_stat_mean          44
# 起付标准以上自负比例金额_max         44
# 药品费发生金额_max              43
# 非账户支付金额_q1               43
# 非账户支付金额_max              43
# fee_zifei_mean           42
# 药品费自费金额_mean             42
# 三目统计项目_mean              41
# freq_to_hospital_max     40
# 三目统计项目_std               39
# every_period_2           37
# 药品费发生金额_sum              36
# 治疗费发生金额_mean             35
# 非账户支付金额_q3               35
# 基本医疗保险统筹基金支付金额_q1        35
# total_rate               34
# 基本医疗保险统筹基金支付金额_q3        34
#                        ...
# 一次性医用材料申报金额_q3            2
# 治疗费自费金额_std               2
# 治疗费自费金额_sum               2
# 床位费发生金额_max               2
# 床位费发生金额_std               2
# 床位费申报金额_mean              2
# 检查费申报金额_q2                1
# 检查费发生金额_q2                1
# 民政救助补助金额_max              1
# 贵重检查费金额_sum               1
# 贵重药品发生金额_q2               1
# 贵重检查费金额_max               1
# 城乡救助补助金额_std              1
# 城乡救助补助金额_q1               1
# 补助审批金额_max                1
# 民政救助补助金额_mean             1
# 医疗救助医院申请_std              1
# 医疗救助医院申请_max              1
# 医用材料发生金额_q1               1
# 其它发生金额_q3                 1
# 中草药费发生金额_q1               1
# every_period_28           1
# 中成药费发生金额_q1               1
# 三目统计项目_q3                 1
# 补助审批金额_q3                 1
# 治疗费自费金额_q3                1
# 补助审批金额_q1                 1
# 补助审批金额_mean               1
# 药品费发生金额_q1                1
# 治疗费申报金额_q1                1
# dtype: int64

# %% [markdown]
# Here, we can not see the improvement in score. So the final parameters are:
#
# max_depth: 4
# min_child_weight: 3
# gamma: 0

# %% [markdown]
# ## Tune subsample and colsample_bytree

# %%
param_test4 = {
 'subsample':[i/10.0 for i in range(7,10)],
 'colsample_bytree':[i/10.0 for i in range(7,10)]
}
gsearch4 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=127, max_depth=6,
 min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test4, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch4.fit(df_train[predictors],df_train[target])
gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# ([mean: 0.91013, std: 0.01324, params: {'subsample': 0.7, 'colsample_bytree': 0.7},
#   mean: 0.91267, std: 0.00947, params: {'subsample': 0.8, 'colsample_bytree': 0.7},
#   mean: 0.91377, std: 0.00990, params: {'subsample': 0.9, 'colsample_bytree': 0.7},
#   mean: 0.91182, std: 0.01052, params: {'subsample': 0.7, 'colsample_bytree': 0.8},
#   mean: 0.91414, std: 0.01062, params: {'subsample': 0.8, 'colsample_bytree': 0.8},
#   mean: 0.91004, std: 0.01459, params: {'subsample': 0.9, 'colsample_bytree': 0.8},
#   mean: 0.91027, std: 0.01083, params: {'subsample': 0.7, 'colsample_bytree': 0.9},
#   mean: 0.91432, std: 0.01266, params: {'subsample': 0.8, 'colsample_bytree': 0.9},
#   mean: 0.91156, std: 0.00823, params: {'subsample': 0.9, 'colsample_bytree': 0.9}],
#  {'colsample_bytree': 0.9, 'subsample': 0.8},
#  0.9143240131578947)

# %%
param_test5 = {
 'subsample':[i/100.0 for i in range(75,90,5)],
 'colsample_bytree':[i/100.0 for i in range(85,100,5)]
}
gsearch5 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=127, max_depth=6,
 min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.9,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test5, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch5.fit(df_train[predictors],df_train[target])
gsearch5.grid_scores_, gsearch4.best_params_, gsearch4.best_score_

# %% [markdown]
# ## Step 5: Tuning Regularization Parameters

# %%
# 'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
param_test6 = {
 'reg_alpha':[0,1e-5, 1e-2, 0.1]
}
gsearch6 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=126, max_depth=6,
 min_child_weight=2, gamma=0, subsample=0.8, colsample_bytree=0.9,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test6, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch6.fit(df_train[predictors],df_train[target])
gsearch6.grid_scores_, gsearch6.best_params_, gsearch6.best_score_
# Out:
# ([mean: 0.91439, std: 0.01242, params: {'reg_alpha': 0},
#   mean: 0.91439, std: 0.01242, params: {'reg_alpha': 1e-05},
#   mean: 0.91603, std: 0.01417, params: {'reg_alpha': 0.01},
#   mean: 0.91152, std: 0.01001, params: {'reg_alpha': 0.1}],
#  {'reg_alpha': 0.01},
#  0.9160300164473684)

# %%
param_test6 = {
 'reg_alpha':[0,1e-06,1e-05]
}
gsearch6 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=55, max_depth=7,
 min_child_weight=1, gamma=0, subsample=0.9, colsample_bytree=0.9,
 objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27), 
 param_grid = param_test6, scoring='roc_auc',n_jobs=4,iid=False, cv=5)
gsearch6.fit(df_train[predictors],df_train[target])
gsearch6.grid_scores_, gsearch6.best_params_, gsearch6.best_score_
# Out:
# ([mean: 0.91402, std: 0.01244, params: {'reg_alpha': 0},
#   mean: 0.91402, std: 0.01244, params: {'reg_alpha': 1e-06},
#   mean: 0.91402, std: 0.01244, params: {'reg_alpha': 1e-05}],
#  {'reg_alpha': 0},
#  0.9140180921052631)

# %%
xgb3 = XGBClassifier(
 learning_rate =0.1,
 n_estimators=1000,
 max_depth=6,
 min_child_weight=2,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.9,
 reg_alpha=0.01,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb3, df_train,df_test, predictors)
# Out:
# [0]	train-auc:0.828698+0.015727	test-auc:0.796258+0.0302
# [10]	train-auc:0.919827+0.00624446	test-auc:0.870441+0.0196063
# [20]	train-auc:0.953242+0.00321259	test-auc:0.891172+0.0134382
# [30]	train-auc:0.972086+0.00134017	test-auc:0.900607+0.00960175
# [40]	train-auc:0.983972+0.000519021	test-auc:0.907846+0.00937015
# [50]	train-auc:0.990718+0.000424028	test-auc:0.910055+0.0087936
# [60]	train-auc:0.994683+0.000345853	test-auc:0.911364+0.00811844
# [70]	train-auc:0.996701+0.000238525	test-auc:0.911862+0.00733672
# [80]	train-auc:0.998152+0.000184356	test-auc:0.911269+0.00695585
# [90]	train-auc:0.99907+0.00018035	test-auc:0.910118+0.00725392
# [100]	train-auc:0.999499+0.000117546	test-auc:0.91+0.00703151
# [110]	train-auc:0.999772+6.50704e-05	test-auc:0.910478+0.0064354
#
# Model Report
# n_estimators:  64
# Training:
# Accuracy : 0.9771
# F1 Score : 0.703883
# AUC Score (Train): 0.994063
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     15200
#           1       1.00      0.54      0.70       800
#
# avg / total       0.98      0.98      0.97     16000
#
#
# Testing:
# Accuracy : 0.965
# F1 Score : 0.503546
# AUC Score (Test): 0.919157
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      3800
#           1       0.87      0.35      0.50       200
#
# avg / total       0.96      0.96      0.96      4000
# trans_stat_sum          85
# every_ave_period        66
# total_trans_rate        60
# total_period            48
# every_q3_period         46
# every_max_period        43
# num_total_hospitals     39
# 中成药费发生金额_max            39
# 三目统计项目_sum              34
# 非账户支付金额_max             33
# 起付标准以上自负比例金额_max        32
# freq_to_hospital_max    31
# fee_zifei_mean          31
# trans_stat_std          30
# 药品费发生金额_max             30
# 三目统计项目_mean             29
# 药品费自费金额_mean            28
# 基本医疗保险个人账户支付金额_mean     28
# last_time               27
# trans_stat_q3           27
# trans_stat_max          27
# every_period_2          27
# 贵重药品发生金额_max            26
# 药品费自费金额_std             25
# num_diff_hospitals      22
# 药品费申报金额_max             22
# 药品费发生金额_sum             22
# total_rate              22
# 中草药费发生金额_max            22
# trans_stat_mean         21
#                         ..
# 治疗费自费金额_max              2
# 一次性医用材料申报金额_q2           2
# every_period_15          1
# 基本医疗保险个人账户支付金额_q1        1
# 贵重检查费金额_max              1
# 检查费发生金额_q2               1
# 医用材料费自费金额_q3             1
# 医用材料发生金额_q3              1
# 贵重检查费金额_std              1
# every_min_period         1
# 贵重检查费金额_sum              1
# 治疗费发生金额_q2               1
# every_period_18          1
# 检查费发生金额_q3               1
# 民政救助补助金额_std             1
# 一次性医用材料申报金额_q3           1
# 治疗费申报金额_q1               1
# 民政救助补助金额_q1              1
# 治疗费自费金额_q3               1
# 检查费自费金额_mean             1
# 城乡救助补助金额_q3              1
# fee_fasheng_sum          1
# 补助审批金额_max               1
# 中成药费发生金额_q1              1
# 床位费发生金额_max              1
# 城乡救助补助金额_std             1
# 医疗救助医院申请_sum             1
# every_period_25          1
# 床位费发生金额_std              1
# 城乡救助补助金额_max             1
# dtype: int64

# %% [markdown]
# 方案1
# - ** 最优参数1**
#
# params = dict(learning_rate =0.1, n_estimators=60, max_depth=7, min_child_weight=1,gamma=0,subsample=0.9, colsample_bytree=0.9, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# - ** 最优参数2**
#
# params = dict(learning_rate =0.01, n_estimators=725, max_depth=7, min_child_weight=1,gamma=0,subsample=0.9, colsample_bytree=0.9, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
#
# 方案2
# - ** 最优参数1**
#
# XGBClassifier(learning_rate =0.1, n_estimators=97, max_depth=8, min_child_weight=2, gamma=0.1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# threhold = 0.17
#
# - ** 最优参数2**
#
# XGBClassifier(learning_rate =0.01, n_estimators=872, max_depth=8, min_child_weight=2, gamma=0.1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)

# %% [markdown]
# ## Step 6: Reducing Learning Rate

# %%
xgb4 = XGBClassifier(
 learning_rate =0.01,
 n_estimators=5000,
 max_depth=6,
 min_child_weight=2,
 gamma=0,
 subsample=0.8,
 colsample_bytree=0.9,
 reg_alpha=0.01,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
modelfit(xgb4, df_train,df_test, predictors)
# Out:
# [0]	train-auc:0.828698+0.015727	test-auc:0.796258+0.0302
# [10]	train-auc:0.884007+0.00504465	test-auc:0.848376+0.0250754
# [20]	train-auc:0.89195+0.00651916	test-auc:0.854554+0.0261137
# [30]	train-auc:0.900842+0.00639793	test-auc:0.862149+0.0238279
# [40]	train-auc:0.905426+0.00367384	test-auc:0.865943+0.0230876
# [50]	train-auc:0.910801+0.00369366	test-auc:0.868706+0.0230948
# [60]	train-auc:0.916274+0.00342393	test-auc:0.873383+0.0205959
# [70]	train-auc:0.920721+0.00407847	test-auc:0.87629+0.0192547
# [80]	train-auc:0.924563+0.00430832	test-auc:0.879477+0.0174385
# [90]	train-auc:0.927805+0.0037564	test-auc:0.881367+0.0161062
# [100]	train-auc:0.932275+0.00301169	test-auc:0.885967+0.0118754
# [110]	train-auc:0.935084+0.00271629	test-auc:0.888376+0.0105033
# [120]	train-auc:0.937847+0.00232532	test-auc:0.888847+0.0108763
# [130]	train-auc:0.940518+0.00224995	test-auc:0.889901+0.0103868
# [140]	train-auc:0.943287+0.00224343	test-auc:0.891126+0.0100171
# [150]	train-auc:0.945757+0.0018448	test-auc:0.892735+0.00986155
# [160]	train-auc:0.948011+0.00206217	test-auc:0.89452+0.00915846
# [170]	train-auc:0.950299+0.00221518	test-auc:0.895633+0.00884162
# [180]	train-auc:0.95239+0.00210195	test-auc:0.896831+0.00856471
# [190]	train-auc:0.95436+0.00184928	test-auc:0.897427+0.0077466
# [200]	train-auc:0.95621+0.00167266	test-auc:0.898164+0.00769362
# [210]	train-auc:0.957986+0.00183857	test-auc:0.898713+0.00795215
# [220]	train-auc:0.95987+0.00161667	test-auc:0.899623+0.00760279
# [230]	train-auc:0.961749+0.00146381	test-auc:0.900181+0.0076154
# [240]	train-auc:0.963559+0.00141962	test-auc:0.901293+0.00794719
# [250]	train-auc:0.965302+0.00124171	test-auc:0.901892+0.00796204
# [260]	train-auc:0.966856+0.00122474	test-auc:0.902541+0.00779357
# [270]	train-auc:0.968455+0.00119346	test-auc:0.90353+0.00761792
# [280]	train-auc:0.97018+0.0010947	test-auc:0.904615+0.0075209
# [290]	train-auc:0.971755+0.00105496	test-auc:0.905218+0.00762433
# [300]	train-auc:0.973494+0.0010153	test-auc:0.905905+0.00763091
# [310]	train-auc:0.975091+0.00080659	test-auc:0.906762+0.00746126
# [320]	train-auc:0.976604+0.000644962	test-auc:0.907764+0.00721166
# [330]	train-auc:0.978189+0.000447237	test-auc:0.908448+0.00733288
# [340]	train-auc:0.979555+0.000311585	test-auc:0.90916+0.00751298
# [350]	train-auc:0.980876+0.000218882	test-auc:0.90994+0.0075263
# [360]	train-auc:0.982023+0.000247163	test-auc:0.910348+0.00754556
# [370]	train-auc:0.983169+0.000284493	test-auc:0.910947+0.00763929
# [380]	train-auc:0.984105+0.000293425	test-auc:0.911304+0.00784255
# [390]	train-auc:0.985049+0.000261661	test-auc:0.911896+0.00785485
# [400]	train-auc:0.985908+0.000236843	test-auc:0.912121+0.00775336
# [410]	train-auc:0.986794+0.000315671	test-auc:0.912592+0.00781451
# [420]	train-auc:0.987575+0.000375588	test-auc:0.912792+0.00789054
# [430]	train-auc:0.988336+0.000346075	test-auc:0.913229+0.00787413
# [440]	train-auc:0.988994+0.000297622	test-auc:0.913444+0.00794674
# [450]	train-auc:0.9896+0.000287284	test-auc:0.913643+0.00802584
# [460]	train-auc:0.990229+0.000284085	test-auc:0.913725+0.00790758
# [470]	train-auc:0.990783+0.000294803	test-auc:0.914085+0.00783006
# [480]	train-auc:0.991266+0.000301588	test-auc:0.914313+0.00773818
# [490]	train-auc:0.991786+0.000309258	test-auc:0.914484+0.00775548
# [500]	train-auc:0.992255+0.000327151	test-auc:0.914742+0.00758577
# [510]	train-auc:0.992672+0.000312779	test-auc:0.914824+0.00745622
# [520]	train-auc:0.993094+0.000309101	test-auc:0.915002+0.0075577
# [530]	train-auc:0.993473+0.000322335	test-auc:0.915235+0.0076077
# [540]	train-auc:0.993827+0.000294611	test-auc:0.915368+0.00771482
# [550]	train-auc:0.994159+0.000269031	test-auc:0.915622+0.00764001
# [560]	train-auc:0.99448+0.000252006	test-auc:0.915787+0.00787425
# [570]	train-auc:0.994761+0.000256111	test-auc:0.916003+0.00780089
# [580]	train-auc:0.99503+0.000238096	test-auc:0.916146+0.00778898
# [590]	train-auc:0.995269+0.000235671	test-auc:0.916144+0.007726
# [600]	train-auc:0.99557+0.000228209	test-auc:0.9163+0.00765433
# [610]	train-auc:0.995792+0.000223554	test-auc:0.916528+0.00769695
# [620]	train-auc:0.99602+0.000196192	test-auc:0.916646+0.00766361
# [630]	train-auc:0.996225+0.00018278	test-auc:0.916699+0.00756279
# [640]	train-auc:0.996422+0.000147	test-auc:0.916855+0.00743044
# [650]	train-auc:0.996584+0.000136961	test-auc:0.916949+0.00732676
# [660]	train-auc:0.996752+0.00013463	test-auc:0.917015+0.00731464
# [670]	train-auc:0.996921+0.000129747	test-auc:0.917062+0.00720427
# [680]	train-auc:0.997106+0.000115476	test-auc:0.917123+0.00712376
# [690]	train-auc:0.997251+0.000110271	test-auc:0.917204+0.00720757
# [700]	train-auc:0.997391+0.000103141	test-auc:0.917281+0.0071636
# [710]	train-auc:0.997516+9.11109e-05	test-auc:0.917325+0.0072364
# [720]	train-auc:0.997654+8.95424e-05	test-auc:0.917394+0.00725338
# [730]	train-auc:0.997796+6.71994e-05	test-auc:0.917445+0.00724546
# [740]	train-auc:0.99792+7.66681e-05	test-auc:0.917369+0.00731229
# [750]	train-auc:0.998045+7.47031e-05	test-auc:0.917414+0.00735716
# [760]	train-auc:0.998157+7.53642e-05	test-auc:0.91752+0.00737995
# [770]	train-auc:0.998249+6.46529e-05	test-auc:0.91758+0.00739949
# [780]	train-auc:0.998352+6.73813e-05	test-auc:0.917671+0.00742532
# [790]	train-auc:0.998444+6.4526e-05	test-auc:0.917681+0.0073994
# [800]	train-auc:0.998536+5.83232e-05	test-auc:0.917736+0.00743532
# [810]	train-auc:0.998628+6.56676e-05	test-auc:0.917726+0.00751364
# [820]	train-auc:0.998705+6.31569e-05	test-auc:0.917768+0.00752389
# [830]	train-auc:0.998788+6.15877e-05	test-auc:0.917849+0.00742832
# [840]	train-auc:0.998868+6.6864e-05	test-auc:0.917707+0.00741015
# [850]	train-auc:0.998936+6.42669e-05	test-auc:0.917698+0.00751638
# [860]	train-auc:0.999011+4.74198e-05	test-auc:0.917618+0.00756595
# [870]	train-auc:0.99907+5.39941e-05	test-auc:0.917703+0.00765463
# [880]	train-auc:0.99912+5.3749e-05	test-auc:0.917708+0.00768436
#
# Model Report
# n_estimators:  832
# Training:
# Accuracy : 0.9831
# F1 Score : 0.796992
# AUC Score (Train): 0.997729
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     15200
#           1       1.00      0.66      0.80       800
#
# avg / total       0.98      0.98      0.98     16000
#
#
# Testing:
# Accuracy : 0.9647
# F1 Score : 0.498221
# AUC Score (Test): 0.924104
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      3800
#           1       0.86      0.35      0.50       200
#
# avg / total       0.96      0.96      0.96      4000
# trans_stat_sum          850
# total_trans_rate        679
# every_ave_period        660
# every_q3_period         584
# total_period            543
# num_total_hospitals     437
# every_max_period        434
# 起付标准以上自负比例金额_max        425
# 中成药费发生金额_max            417
# last_time               414
# freq_to_hospital_max    364
# 三目统计项目_sum              357
# trans_stat_std          353
# trans_stat_q3           352
# 贵重药品发生金额_max            314
# 三目统计项目_std              297
# total_rate              292
# 药品费发生金额_max             291
# 药品费自费金额_sum             287
# 非账户支付金额_max             284
# 三目统计项目_mean             280
# trans_stat_max          277
# fee_zifei_mean          276
# trans_stat_mean         266
# 基本医疗保险统筹基金支付金额_q3       256
# 中成药费发生金额_std            255
# every_period_2          248
# 贵重药品发生金额_sum            246
# 治疗费发生金额_std             245
# 药品费发生金额_sum             245
#                        ...
# 医用材料发生金额_q2               6
# 城乡救助补助金额_mean             6
# 床位费申报金额_mean              6
# 贵重检查费金额_std               6
# 床位费申报金额_std               6
# every_period_25           5
# 公务员医疗补助基金支付金额_max         5
# 医用材料发生金额_q1               5
# 其它发生金额_q3                 5
# 治疗费申报金额_q1                5
# 基本医疗保险个人账户支付金额_q1         4
# 医用材料费自费金额_q3              4
# 床位费申报金额_sum               4
# 医疗救助医院申请_std              4
# every_period_21           3
# 高价材料发生金额_mean             3
# 公务员医疗补助基金支付金额_q2          3
# 民政救助补助金额_q3               3
# every_period_27           3
# 一次性医用材料申报金额_q2            3
# 检查费申报金额_q2                3
# 药品费自费金额_q2                2
# every_period_30           2
# 三目统计项目_q1                 2
# 民政救助补助金额_max              2
# 一次性医用材料申报金额_q1            2
# 床位费申报金额_max               1
# 床位费发生金额_q3                1
# fee_buzhu_sum             1
# 高价材料发生金额_std              1
# dtype: int64

# %% [markdown]
# # Best Model Analysis

# %% [markdown]
# ## Training and Prediction

# %%
rf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=5, min_samples_split=30,
            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
rf.fit(df_train[predictors],df_train[target])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=30, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
# predict on testing data:
df_test_predictions = rf.predict(df_test[predictors])
df_test_predprob = rf.predict_proba(df_test[predictors])[:,1]

print "Accuracy : %.4g" % metrics.accuracy_score(df_test[target], df_test_predictions)
print "F1 Score : %f" % metrics.f1_score(df_test[target],df_test_predictions)
print 'AUC Score (Test): %f' % metrics.roc_auc_score(df_test[target], df_test_predprob)
print "Classification Report : \n", metrics.classification_report(df_test[target],df_test_predictions)

rcParams['figure.figsize'] = 12,4
feat_imp = pd.Series(rf.feature_importances_,index=predictors).sort_values(ascending=False)
feat_imp[0:60].plot(kind='bar', title='Feature Importance')
plt.ylabel('Feature Importance Score')
# Out:
# Accuracy : 0.963
# F1 Score : 0.430769
# AUC Score (Test): 0.915455
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      3800
#           1       0.93      0.28      0.43       200
#
# avg / total       0.96      0.96      0.95      4000

# %%
feat_imp.size
# Out:
# 3578

# %% [markdown]
# ## Plotting confusion matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
plt.ion()

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        1#print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### On Test Data Set

# %%
#df_test_predictions = xgb.predict(dtest[predictors])
#df_test_predprob = xgb.predict_proba(dtest[predictors])[:,1]

#y_pred = np.zeros_like(y_pred_proba)
#y_pred[y_pred_proba>0.03] = 1  # 大于0.03预测为正例

print "F1 score: ", metrics.f1_score(df_test[target], df_test_predictions)

# confusion matrix
cnf_matrix = confusion_matrix(df_test[target], df_test_predictions)
np.set_printoptions(precision=2)

print "Recall metric in testing dataset: ", float(cnf_matrix[1,1])/(cnf_matrix[1,0]+cnf_matrix[1,1])

# plot non_normalized confusion matrix
class_names = [0,1]
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, title='Confusion matrix - Test Set')
plt.show()
# Out:
# F1 score:  0.430769230769
# Recall metric in testing dataset:  0.28

# %% [markdown]
# ### On Whole Data Set

# %%
df_train_test_predictions = rf.predict(df_train_test[predictors])
df_train_test_predprob = rf.predict_proba(df_train_test[predictors])[:,1]
print "F1 score: ", metrics.f1_score(df_train_test[target], df_train_test_predictions)

# confusion matrix
cnf_matrix = confusion_matrix(df_train_test[target], df_train_test_predictions)
np.set_printoptions(precision=2)

print "Recall metric in testing dataset: ", float(cnf_matrix[1,1])/(cnf_matrix[1,0]+cnf_matrix[1,1])

# plot non_normalized confusion matrix
class_names = [0,1]
plt.figure()
plot_confusion_matrix(cnf_matrix, classes = class_names, title='Confusion matrix - Whole Set')
plt.show()
# Out:
# F1 score:  0.41065830721
# Recall metric in testing dataset:  0.262

# %% [markdown]
# ## ROC curve

# %%
from sklearn.metrics import roc_curve, auc
rcParams['figure.figsize'] = 6.4,4.8
#df_test_predictions = xgb.predict(dtest[predictors])
#df_test_predprob = xgb.predict_proba(dtest[predictors])[:,1]
fpr, tpr, thresholds = roc_curve(df_test[target].values,df_test_predprob)
# Plot Precision-Recall curve
plt.plot(fpr, tpr, color='r')
plt.xlabel('FPR')
plt.ylabel('TPR-Recall')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('ROC')
plt.legend()

# %% [markdown]
# ## Precision-Recall curve

# %%
from sklearn.metrics import precision_recall_curve
rcParams['figure.figsize'] = 6.4,4.8
precision, recall, thresholds = precision_recall_curve(df_test[target].values,df_test_predprob)
# Plot Precision-Recall curve
plt.plot(recall, precision, color='r')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall example')
plt.legend()

# %% [markdown]
# # Optimization: Changing Threshold

# %% [markdown]
# ## Precision and Recall

# %%
from itertools import cycle
from sklearn.metrics import precision_recall_curve

#df_test_predictions = xgb.predict(df_test[predictors])
df_test_predprob = rf.predict_proba(df_test[predictors])[:,1]

thresholds = np.arange(1,10)/10.0
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal', 'red', 'yellow', 'green', 'blue','black'])

plt.figure(figsize=(5,5))

j = 1
for i,color in zip(thresholds,colors):
    y_test_predictions_prob = df_test_predprob > i
    
    #print "Threshold: ",i,", F1 score:", f1_score(df_test[target],y_test_predictions_prob)
    
    precision, recall, thresholds = precision_recall_curve(df_test[target],y_test_predictions_prob)
    print "Threshold: ",i,", F1 score:", 2*precision*recall/(precision+recall)
    print precision, recall, thresholds
    
    # Plot Precision-Recall curve
    plt.plot(recall, precision, color=color,
                 label='Threshold: %s'%i)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall example')
    plt.legend()
# Out:
# Threshold:  0.1 , F1 score: [ 0.1   0.43  0.  ]
# [ 0.05  0.29  1.  ] [ 1.    0.77  0.  ] [False  True]
# Threshold:  0.2 , F1 score: [ 0.1  0.5  0. ]
# [ 0.05  0.52  1.  ] [ 1.    0.47  0.  ] [False  True]
# Threshold:  0.3 , F1 score: [ 0.1   0.47  0.  ]
# [ 0.05  0.68  1.  ] [ 1.    0.35  0.  ] [False  True]
# Threshold:  0.4 , F1 score: [ 0.1   0.42  0.  ]
# [ 0.05  0.89  1.  ] [ 1.    0.28  0.  ] [False  True]
# Threshold:  0.5 , F1 score: [ 0.1   0.37  0.  ]
# [ 0.05  0.98  1.  ] [ 1.    0.23  0.  ] [False  True]
# Threshold:  0.6 , F1 score: [ 0.1   0.31  0.  ]
# [ 0.05  1.    1.  ] [ 1.    0.18  0.  ] [False  True]
# Threshold:  0.7 , F1 score: [ 0.1   0.21  0.  ]
# [ 0.05  1.    1.  ] [ 1.    0.12  0.  ] [False  True]
# Threshold:  0.8 , F1 score: [ 0.1   0.13  0.  ]
# [ 0.05  1.    1.  ] [ 1.    0.07  0.  ] [False  True]
# Threshold:  0.9 , F1 score: [ 0.1   0.08  0.  ]
# [ 0.05  1.    1.  ] [ 1.    0.04  0.  ] [False  True]

# %% [markdown]
# ## Confusion Matrix

# %%
thresholds = np.arange(1,10)/20.0
plt.figure(figsize=(12,12))
j  = 1
for i in thresholds:
    y_test_predictions_high_recall = df_test_predprob > i
    plt.subplot(3,3,j)
    j += 1
    
    # compute confusion matrix
    cnf_matrix = confusion_matrix(df_test[target], y_test_predictions_high_recall)
    #print "Recall metric in the testing dataset: ", float(cnf_matrix[1,1])/(cnf_matrix[0,1]+cnf_matrix[1,1])
    print "Threhold >= %s, "%i,"F1 score: ", metrics.f1_score(df_test[target], y_test_predictions_high_recall)
    
    # plot non-normalized confusion matrix
    class_names = [0,1]
    plot_confusion_matrix(cnf_matrix,classes=class_names,title='Threhold >= %s'%i)
# Out:
# Threhold >= 0.05,  F1 score:  0.288357748651
# Threhold >= 0.1,  F1 score:  0.425414364641
# Threhold >= 0.15,  F1 score:  0.472049689441
# Threhold >= 0.2,  F1 score:  0.496083550914
# Threhold >= 0.25,  F1 score:  0.466666666667
# Threhold >= 0.3,  F1 score:  0.467105263158
# Threhold >= 0.35,  F1 score:  0.435714285714
# Threhold >= 0.4,  F1 score:  0.419847328244
# Threhold >= 0.45,  F1 score:  0.377510040161

# %% [markdown]
# ## Threshold CV for F1 Score

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

def threshold_search(estimator,thresholds,train,kf=5,random_state=27,stratify=False):
    cv_result = [] 
    
    if stratify:
        kf = StratifiedKFold(n_splits=kf,random_state=random_state)
    else:
        kf = KFold(n_splits=kf,random_state=random_state)
        
    for threshold in thresholds:
        score = []
        for idx_train,idx_test in kf.split(train[predictors].values,train[target].values):  # 划分k折
            estimator.fit(train[predictors].values[idx_train,:],train[target].values[idx_train])  # 这里predictors,target，作为全局参数
            #pred = estimator.predict(train[predictors].values[idx_test,:])
            predprob = estimator.predict_proba(train[predictors].values[idx_test,:])
            pred = predprob[:,1] >= threshold
            score.append(metrics.f1_score(train[target].values[idx_test],pred))  # f1 score
        cv_result.append([np.array(score).mean(),np.array(score).std(),threshold])
    return sorted(cv_result,reverse=True)

# %%
# Best model with threshold = 0.5
thresholds = [0.17,0.18]

xgb = XGBClassifier(
 learning_rate =0.01,
 n_estimators=872,
 max_depth=8,
 min_child_weight=2,
 gamma=0.1,
 subsample=0.8,
 colsample_bytree=0.8,
 reg_alpha=0,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)

cv_result = threshold_search(xgb,thresholds,df_train,kf=5,random_state=27,stratify=False)

# %%
best_threshold = cv_result[0][-1]
cv_result   # [0.48692599096168082, 0.0082032694157471928, 0.15]
            # [0.49062021225829094, 0.0082035229949767238, 0.16]
# Out:
# [[0.48906596870909153, 0.01064908676639861, 0.17],
#  [0.48404899659186251, 0.0098264116966037245, 0.18]]

# %%
xgb = XGBClassifier(
 learning_rate =0.005,
 n_estimators=1550,
 max_depth=8,
 min_child_weight=2,
 gamma=0.1,
 subsample=0.8,
 colsample_bytree=0.8,
 reg_alpha=0,
 objective= 'binary:logistic',
 nthread=4,
 scale_pos_weight=1,
 seed=27)
xgb.fit(df_train[predictors],df_train[target])
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.8,
#        gamma=0.1, learning_rate=0.005, max_delta_step=0, max_depth=8,
#        min_child_weight=2, missing=None, n_estimators=1550, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=27, silent=True, subsample=0.8)

# %%
# predict on testing data:
#df_test_predictions = xgb.predict(df_test[predictors])
df_test_predprob = xgb.predict_proba(df_test[predictors])[:,1]
df_test_predictions = df_test_predprob>= 0.198

print "Accuracy : %.4g" % metrics.accuracy_score(df_test[target], df_test_predictions)
print "F1 Score : %f" % metrics.f1_score(df_test[target],df_test_predictions)
print 'AUC Score (Test): %f' % metrics.roc_auc_score(df_test[target], df_test_predprob)
print "Classification Report : \n", metrics.classification_report(df_test[target],df_test_predictions)
# Out:
# Accuracy : 0.966
# F1 Score : 0.604651
# AUC Score (Test): 0.921837
# Classification Report :
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      3800
#           1       0.72      0.52      0.60       200
#
# avg / total       0.96      0.97      0.96      4000

# %% [markdown]
# ## Opimal Models

# %% [markdown]
# 发现当scal_pos_weight=1时，f1最值对于threshold非常敏感，可保留到小数点后3位。
# 也许设置scal_pos_weight>1,会降低f1对threshold的敏感性？
#
# **基于新的（稀疏特征被丢弃）未处理的特征数据（std==0未处理）**
# - **（1）scale_pos_weight=1；新的未处理的特征数据（std==0未处理）[完成]**
#     - **模型参数1**  - f1_score：0.567442
# params = dict(learning_rate =0.1, n_estimators=60, max_depth=7, min_child_weight=1,gamma=0,subsample=0.9, colsample_bytree=0.9, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# threhold = 0.16
#     - **模型参数2**
# params = dict(learning_rate =0.01, n_estimators=725, max_depth=7, min_child_weight=1,gamma=0,subsample=0.9, colsample_bytree=0.9, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# threhold = 0.15
# - **（2）scale_pos_weight=1；特征数据清洗（std==0删除）[完成]**
#     - **模型参数1**  - f1_score：0.583756
# XGBClassifier(learning_rate =0.1, n_estimators=97, max_depth=8, min_child_weight=2, gamma=0.1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# threhold = 0.17
#
#     - **模型参数2**   -f1_score：0.584270；  调节threshold能达到0.5892
# XGBClassifier(learning_rate =0.01, n_estimators=872, max_depth=8, min_child_weight=2, gamma=0.1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0, objective= 'binary:logistic', nthread=4, scale_pos_weight=1, seed=27)
# threhold = 0.16
# n_estimators=1550, learning_rate=0.005, threhold=0.21，f1_score=0.61
#     - **（3）scale_pos_weight=1；特征数据清洗（std==0删除）+额外构造的fee特征**   f1_score=0.605
# XGBClassifier( learning_rate =0.1, n_estimators=64, max_depth=6, min_child_weight=2, gamma=0,subsample=0.8,
#  colsample_bytree=0.9, reg_alpha=0.01, objective= 'binary:logistic', nthread=4, scale_pos_weight=1,seed=27)
# threhold = 0.28
# XGBClassifier( learning_rate =0.005, n_estimators=64, max_depth=6, min_child_weight=2,gamma=0,subsample=0.8, colsample_bytree=0.9, reg_alpha=0.01, objective='binary:logistic', nthread=4, scale_pos_weight=1,seed=27)
# threshold = 0.198  f1-score:0.604651
# - **（4）scale_pos_weight=1；特征数据清洗（std==0删除）+额外构造的fee特征-最不重要的特征（出现一二次）**
# - **（5）scale_pos_weight=1；特征数据清洗（std==0删除）+额外构造的fee特征+稀疏特征**
#
#
#
# **试验方案：** first_time，last_time都去掉,这两个特征毫无逻辑？？
# 但last_time似乎还很重要？why？？也许绝大多数正常者，不常去医院，亦或者年底比较好fraud？还是先保留last_time
# 删除first_time是因为在测试数据集中first_time都在年中开始！数据分布不一致！！
#
# （1）scale_pos_weight=1；新的未处理的特征数据（std==0）[完成]
# （3）scale_pos_weight=1；去除std==0特征数据
# （5）scale_pos_weight=1；去除不重要特征，如first_time等（去除只出现一次的特征）
#
# （2）scale_pos_weight=3；新的未处理的特征数据（std==0）
# （4）scale_pos_weight=3；去除std==0特征数据
# （6）scale_pos_weight=3；去除不重要特征，如first_time等（去除只出现一次的特征）

# %% [markdown]
# # Drop Unimportant Features

# %%
feat_imp[feat_imp<=2]
# Out:
# every_q2_period       2
# 治疗费申报金额_q2            2
# 医用材料费自费金额_max         2
# every_period_9        2
# 药品费发生金额_q1            2
# every_period_23       2
# every_period_17       2
# every_period_16       2
# every_period_15       2
# every_period_0        2
# 补助审批金额_q3             2
# 贵重检查费金额_max           2
# dayofweek_5           2
# 贵重检查费金额_sum           2
# 治疗费发生金额_q2            2
# 治疗费发生金额_q1            2
# 医疗救助医院申请_std          2
# 三目统计项目_max            2
# 中草药费发生金额_q3           2
# 医疗救助医院申请_max          2
# 医用材料费自费金额_sum         2
# 医用材料费自费金额_std         2
# 医用材料费自费金额_mean        2
# 贵重检查费金额_mean          1
# every_period_10       1
# 贵重药品发生金额_q3           1
# 补助审批金额_max            1
# 补助审批金额_mean           1
# 补助审批金额_q1             1
# 公务员医疗补助基金支付金额_q2      1
#                      ..
# 医用材料发生金额_q2           1
# 医疗救助个人按比例负担金额_mean    1
# 医用材料发生金额_q3           1
# every_period_18       1
# 贵重检查费金额_std           1
# 补助审批金额_std            1
# 医用材料发生金额_q1           1
# 中草药费发生金额_q2           1
# 民政救助补助金额_sum          1
# 民政救助补助金额_q2           1
# 床位费发生金额_std           1
# 民政救助补助金额_q1           1
# 民政救助补助金额_mean         1
# 检查费自费金额_sum           1
# 治疗费申报金额_q3            1
# 检查费发生金额_q2            1
# 治疗费自费金额_mean          1
# 床位费申报金额_sum           1
# 治疗费自费金额_q3            1
# 治疗费自费金额_std           1
# 城乡救助补助金额_max          1
# 三目统计项目_q2             1
# 床位费发生金额_max           1
# 药品费申报金额_q1            1
# 城乡救助补助金额_sum          1
# 城乡救助补助金额_q3           1
# 中成药费发生金额_q2           1
# every_period_22       1
# every_period_21       1
# 城乡救助补助金额_q2           1
# dtype: int64

# %%
feat_droped = feat_imp[feat_imp<=2].reset_index()['index'].str.encode('utf-8')

# %%
df_train_test_new = df_train_test.drop(feat_droped,axis=1)

# %%
df_train_test_new.to_csv('df_data_feaure_dropped.csv')
